# %%
# !pip install TTS
# !sudo apt-get install espeak
from TTS.api import TTS
from IPython.display import Audio, display
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 655.3/655.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.0/581.0 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 30.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload() # upload your single wav file from 10-60 seconds get good quality audio no background noise or stuttering
# Out:
#      <input type="file" id="files-665e2ec4-9de6-41be-917f-76cea8b6e926" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-665e2ec4-9de6-41be-917f-76cea8b6e926">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
tts = TTS(model_name="tts_models/multilingual/multi-dataset/your_tts")
# Out:
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--your_tts
# 100%|██████████| 425M/425M [00:08<00:00, 47.5MiB/s]
#  > Model's license - CC BY-NC-ND 4.0
#  > Check https://creativecommons.org/licenses/by-nc-nd/4.0/ for more info.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
# ...

# %%
tts.tts_to_file('Hello there obi wan.', language="en", speaker_wav="iann.wav" )
display(Audio('output.wav', autoplay=True))
# Out:
#  > Text splitted to sentences.
# ['Hello there obi wan.']
#  > Processing time: 2.437591314315796
#  > Real-time factor: 1.4927074796789932
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !git clone https://github.com/jnordberg/tortoise-tts.git
# %cd tortoise-tts
# !pip3 install transformers==4.19.0
# !pip3 install -r requirements.txt
# !python3 setup.py install
# Out:
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1481, done.
# remote: Total 1481 (delta 0), reused 0 (delta 0), pack-reused 1481
# Receiving objects: 100% (1481/1481), 53.57 MiB | 24.51 MiB/s, done.
# Resolving deltas: 100% (596/596), done.
# /content/tortoise-tts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 25.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 18.4 MB/s eta 0:00:00
# ...

# %%
# %cd '/content/tortoise-tts/tortoise/voices'
# !mkdir 'yourvoice'
# %cd yourvoice
from google.colab import files
uploaded = files.upload()# upload 3-5 or more 10 second clips of very quality voice, normalized and no background noise, not silence or uh and ums
# %cd ..
# %cd ..
# %cd ..
# Out:
# /content/tortoise-tts/tortoise/voices
# /content/tortoise-tts/tortoise/voices/yourvoice
#      <input type="file" id="files-f89cf999-8abc-4f8b-ae15-b0b03032385d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f89cf999-8abc-4f8b-ae15-b0b03032385d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# code should run faster after the first time it downloads model weights for inference

# %%
# !python tortoise/do_tts.py --text "I'm going to speak this" --voice random --preset fast
# Out:
# Downloading: 100% 2.06k/2.06k [00:00<00:00, 1.52MB/s]
# Downloading: 100% 1.18G/1.18G [00:19<00:00, 64.3MB/s]
# Downloading: 100% 159/159 [00:00<00:00, 170kB/s]
# Downloading: 100% 1.57k/1.57k [00:00<00:00, 1.54MB/s]
# Downloading: 100% 181/181 [00:00<00:00, 117kB/s]
# Downloading: 100% 85.0/85.0 [00:00<00:00, 87.6kB/s]
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# ...
# 100% ||
# Done.
# Generating autoregressive samples..
# 100% 6/6 [00:12<00:00,  2.02s/it]
# Computing best candidates using CLVP and CVVP
#   0% 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 100% 6/6 [00:04<00:00,  1.36it/s]
# Transforming autoregressive outputs into audio..
# 100% 80/80 [00:04<00:00, 16.36it/s]
# ...

# %% [markdown]
# output is on the side in tortoise tts/results/ you can add extra candidates to be generated or change quality checek documentation at https://github.com/neonbjb/tortoise-tts
